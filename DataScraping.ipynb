# %% [markdown]
# # import

# %%
import pandas as pd
from tqdm.notebook import tqdm as tqdm
import requests
from bs4 import BeautifulSoup
import re
import time
import urllib.request

# %% [markdown]
# # Scraping Race info

# %%
import pandas as pd
import time
from tqdm.notebook import tqdm

def scrape_race_results(race_id_list, pre_race_results={}):
    race_results = pre_race_results
    for race_id in race_id_list:
        if race_id in race_results.keys():
            continue
        try:
            time.sleep(1)
            url = "https://db.netkeiba.com/race/" + race_id
            race_results[race_id] = pd.read_html(url)[0]
        except IndexError:
            continue
        except Exception as e:
            print(e)
            break
        except:
            break
    return race_results

#レースIDのリストを作る
race_id_list = []
for place in range(1, 11, 1):
    for kai in range(1, 6, 1):
        for day in range(1, 13, 1):
            for r in range(1, 13, 1):
                race_id = "2021" + str(place).zfill(2) + str(kai).zfill(2) +\
		str(day).zfill(2) + str(r).zfill(2)
                race_id_list.append(race_id)

#スクレイピングしてデータを保存
test3 = scrape_race_results(race_id_list)
for key in test3:
    test3[key].index = [key] * len(test3[key])
results = pd.concat([test3[key] for key in test3], sort=False) 
# results.to_pickle('results.pickle')
results
# Out:
#               着順  枠番  馬番         馬名  性齢    斤量    騎手     タイム     着差     単勝  \
# 202101010101   1   5   9  ディーバサンライズ  牝3  52.0  秋山稔樹  1:08.7    NaN   13.5
# 202101010101   2   3   6      バンベルク  牡3  56.0  横山和生  1:08.8    3/4    3.9
# 202101010101   3   7  14      リツィタル  牝3  54.0  大野拓弥  1:08.9    1/2  124.7
# 202101010101   4   5  10  クレマチステソーロ  牝3  54.0  鮫島克駿  1:09.0    1/2    7.6
# 202101010101   5   3   5  ペイシャケイティー  牝3  54.0  古川吉洋  1:09.0     ハナ    7.5
# ...           ..  ..  ..        ...  ..   ...   ...     ...    ...    ...
# 202110040812   7   2   2      ジオルティ  牡3  51.0  角田大和  2:42.0  1.1/4   49.6
# 202110040812   8   7   9     ロックグラス  牡4  57.0   幸英明  2:42.2  1.1/4   43.7
# 202110040812   9   7   8    サマーカナロア  牡3  53.0   富田暁  2:42.2     ハナ   46.5
# 202110040812  10   8  10     レッドレイル  セ5  57.0   浜中俊  2:42.4  1.1/4   14.0
# 202110040812  11   6   7   ニシノトランザム  セ6  57.0  西村淳也  2:42.6  1.1/2   82.5
#
#                 人気       馬体重       調教師
# 202101010101   7.0  474(-22)  [西] 小林真也
# 202101010101   2.0   470(-2)  [西] 安田隆行
# 202101010101  14.0   394(+2)  [西] 牧田和弥
# 202101010101   5.0   468(+2)   [東] 高木登
# 202101010101   4.0   456(+8)   [東] 土田稔
# ...            ...       ...       ...
# 202110040812  10.0   502(+8)  [西] 杉山晴紀
# 202110040812   8.0    464(0)    [西] 谷潔
# 202110040812   9.0  502(-10)    [西] 昆貢
# 202110040812   6.0   436(+2)  [西] 辻野泰之
# 202110040812  11.0   486(-2)   [西] 森秀行
#
# [38130 rows x 13 columns]

# %%
results_2021 = results

# %% [markdown]
# # Save race data

# %%
save_path = '/Users/rince/Desktop/Horse/Data/horse_2021.csv'
horse_results.to_csv(save_path)

# %% [markdown]
# # Load Race data

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46968 entries, 202001010101 to 202010020812
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   着順            46968 non-null  object
#  1   枠番            46968 non-null  int64
#  2   馬番            46968 non-null  int64
#  3   馬名            46968 non-null  object
#  4   性齢            46968 non-null  object
#  5   斤量            46968 non-null  float64
#  6   騎手            46968 non-null  object
#  7   タイム           46575 non-null  object
#  8   着差            43213 non-null  object
#  9   単勝            46968 non-null  object
#  10  人気            46816 non-null  float64
#  11  馬体重           46968 non-null  object
#  12  調教師           46968 non-null  object
#  13  course_len    46968 non-null  int64
#  14  weather       46968 non-null  object
#  15  race_type     46968 non-null  object
#  16  ground_state  46968 non-null  object
#  17  date          46968 non-null  object
#  18  horse_id      46968 non-null  int64
#  19  jockey_id     46968 non-null  int64
# dtypes: float64(2), int64(5), object(13)
# memory usage: 7.5+ MB

# %%
load_path = '/Users/rince/Desktop/Horse/Data/2020/results_2020.csv'
results = pd.read_csv(load_path, index_col=0)
results
# Out:
#               着順  枠番  馬番         馬名  性齢    斤量    騎手     タイム     着差    単勝  \
# 202001010101   1   6   6     ウインルーア  牝2  54.0  横山武史  1:49.7    NaN  16.0
# 202001010101   2   2   2     アークライト  牡2  54.0  ルメール  1:50.0  1.3/4   1.9
# 202001010101   3   3   3  ギャラントウォリア  牡2  54.0  池添謙一  1:50.1    1/2   1.8
# 202001010101   4   1   1     ジュンブーケ  牝2  52.0  亀田温心  1:50.5  2.1/2  22.2
# 202001010101   5   4   4    キタノマンゲツ  牡2  54.0  藤岡康太  1:51.0      3  55.7
# ...           ..  ..  ..        ...  ..   ...   ...     ...    ...   ...
# 202010020812  11   1   1       キスラー  牡4  57.0    武豊  1:45.5      1   6.5
# 202010020812  12   8  14    ポンペイワーム  牡4  57.0   浜中俊  1:45.6     クビ  19.8
# 202010020812  13   8  15  アルマトップエンド  牡5  57.0  国分恭介  1:45.9  1.3/4  75.0
# 202010020812  14   2   3      ノイーヴァ  牝4  55.0  太宰啓介  1:46.7      5  46.1
# 202010020812  15   7  13   ナイトオブレディ  牝3  52.0  川又賢治  1:47.5      5  24.7
#
#                 人気       馬体重       調教師  course_len weather race_type  \
# 202001010101   3.0   438(+4)  [東] 青木孝文        1800       曇         芝
# 202001010101   2.0    510(0)  [東] 藤沢和雄        1800       曇         芝
# 202001010101   1.0   482(-6)   [西] 平田修        1800       曇         芝
# 202001010101   4.0    442(0)   [西] 森秀行        1800       曇         芝
# 202001010101   5.0   426(-8)  [西] 中尾秀正        1800       曇         芝
# ...            ...       ...       ...         ...     ...       ...
# 202010020812   4.0   476(-2)  [西] 池江泰寿        1700       雨       ダート
# 202010020812   8.0   522(-8)   [西] 石坂正        1700       雨       ダート
# 202010020812  14.0    510(0)  [西] 佐々木晶        1700       雨       ダート
# 202010020812  10.0  488(-12)  [西] 安田翔伍        1700       雨       ダート
# 202010020812   9.0   468(+2)  [西] 庄野靖志        1700       雨       ダート
#
#              ground_state        date    horse_id  jockey_id
# 202001010101            良  2020年7月25日  2018101626       1170
# 202001010101            良  2020年7月25日  2018105193       5339
# 202001010101            良  2020年7月25日  2018104800       1032
# 202001010101            良  2020年7月25日  2018102410       1176
# 202001010101            良  2020年7月25日  2018100828       1116
# ...                   ...         ...         ...        ...
# 202010020812            重   2020年9月6日  2016105042        666
# 202010020812            重   2020年9月6日  2016110126       1115
# 202010020812            重   2020年9月6日  2015102639       1124
# 202010020812            重   2020年9月6日  2016110067       1037
# 202010020812            重   2020年9月6日  2017105123       1166
#
# [46968 rows x 20 columns]

# %% [markdown]
# # Results class

# %%
class Results:
    @staticmethod
    def scrape(race_id_list):
        #race_idをkeyにしてDataFrame型を格納
        race_results = {}
        for race_id in tqdm(race_id_list, total=len(race_id_list)):
            time.sleep(1)
            try:
                url = "https://db.netkeiba.com/race/" + race_id
                #メインとなるテーブルデータを取得
                df = pd.read_html(url)[0]
                html = requests.get(url)
                html.encoding = "EUC-JP"
                soup = BeautifulSoup(html.text, "html.parser")

                #天候、レースの種類、コースの長さ、馬場の状態、日付をスクレイピング
                texts = (
                    soup.find("div", attrs={"class": "data_intro"}).find_all("p")[0].text
                    + soup.find("div", attrs={"class": "data_intro"}).find_all("p")[1].text
                )
                info = re.findall(r'\w+', texts)
                for text in info:
                    if text in ["芝", "ダート"]:
                        df["race_type"] = [text] * len(df)
                    if "障" in text:
                        df["race_type"] = ["障害"] * len(df)
                    if "m" in text:
                        df["course_len"] = [int(re.findall(r"\d+", text)[0])] * len(df)
                    if text in ["良", "稍重", "重", "不良"]:
                        df["ground_state"] = [text] * len(df)
                    if text in ["曇", "晴", "雨", "小雨", "小雪", "雪"]:
                        df["weather"] = [text] * len(df)
                    if "年" in text:
                        df["date"] = [text] * len(df)

                #馬ID、騎手IDをスクレイピング
                horse_id_list = []
                horse_a_list = soup.find("table", attrs={"summary": "レース結果"}).find_all(
                    "a", attrs={"href": re.compile("^/horse")}
                )
                for a in horse_a_list:
                    horse_id = re.findall(r"\d+", a["href"])
                    horse_id_list.append(horse_id[0])
                jockey_id_list = []
                jockey_a_list = soup.find("table", attrs={"summary": "レース結果"}).find_all(
                    "a", attrs={"href": re.compile("^/jockey")}
                )
                for a in jockey_a_list:
                    jockey_id = re.findall(r"\d+", a["href"])
                    jockey_id_list.append(jockey_id[0])
                df["horse_id"] = horse_id_list
                df["jockey_id"] = jockey_id_list

                #インデックスをrace_idにする
                df.index = [race_id] * len(df)

                race_results[race_id] = df
            #存在しないrace_idを飛ばす
            except IndexError:
                continue
            #wifiの接続が切れた時などでも途中までのデータを返せるようにする
            except Exception as e:
                print(e)
                break
            #Jupyterで停止ボタンを押した時の対処
            except:
                break

        #pd.DataFrame型にして一つのデータにまとめる
        race_results_df = pd.concat([race_results[key] for key in race_results])

        return race_results_df

# %%
# race_id はstr型に変換!!

race_id_list =  results.index.astype('str')
race_id_list
# Out:
# Index(['202001010101', '202001010101', '202001010101', '202001010101',
#        '202001010101', '202001010101', '202001010102', '202001010102',
#        '202001010102', '202001010102',
#        ...
#        '202010020812', '202010020812', '202010020812', '202010020812',
#        '202010020812', '202010020812', '202010020812', '202010020812',
#        '202010020812', '202010020812'],
#       dtype='object', length=46968)

# %%
results['horse_id']
# Out:
# 202001010101    2018101626
# 202001010101    2018105193
# 202001010101    2018104800
# 202001010101    2018102410
# 202001010101    2018100828
#                    ...
# 202010020812    2016105042
# 202010020812    2016110126
# 202010020812    2015102639
# 202010020812    2016110067
# 202010020812    2017105123
# Name: horse_id, Length: 46968, dtype: int64

# %%
results = Results.scrape(race_id_list)
# Out:
#   0%|          | 0/38130 [00:00<?, ?it/s]

# %%
results
# Out:
#               着順  枠番  馬番         馬名  性齢    斤量    騎手     タイム     着差     単勝  \
# 202101010101   1   5   9  ディーバサンライズ  牝3  52.0  秋山稔樹  1:08.7    NaN   13.5
# 202101010101   2   3   6      バンベルク  牡3  56.0  横山和生  1:08.8    3/4    3.9
# 202101010101   3   7  14      リツィタル  牝3  54.0  大野拓弥  1:08.9    1/2  124.7
# 202101010101   4   5  10  クレマチステソーロ  牝3  54.0  鮫島克駿  1:09.0    1/2    7.6
# 202101010101   5   3   5  ペイシャケイティー  牝3  54.0  古川吉洋  1:09.0     ハナ    7.5
# ...           ..  ..  ..        ...  ..   ...   ...     ...    ...    ...
# 202110040812   7   2   2      ジオルティ  牡3  51.0  角田大和  2:42.0  1.1/4   49.6
# 202110040812   8   7   9     ロックグラス  牡4  57.0   幸英明  2:42.2  1.1/4   43.7
# 202110040812   9   7   8    サマーカナロア  牡3  53.0   富田暁  2:42.2     ハナ   46.5
# 202110040812  10   8  10     レッドレイル  セ5  57.0   浜中俊  2:42.4  1.1/4   14.0
# 202110040812  11   6   7   ニシノトランザム  セ6  57.0  西村淳也  2:42.6  1.1/2   82.5
#
#                 人気       馬体重       調教師  course_len weather race_type  \
# 202101010101   7.0  474(-22)  [西] 小林真也        1200      小雨         芝
# 202101010101   2.0   470(-2)  [西] 安田隆行        1200      小雨         芝
# 202101010101  14.0   394(+2)  [西] 牧田和弥        1200      小雨         芝
# 202101010101   5.0   468(+2)   [東] 高木登        1200      小雨         芝
# 202101010101   4.0   456(+8)   [東] 土田稔        1200      小雨         芝
# ...            ...       ...       ...         ...     ...       ...
# 202110040812  10.0   502(+8)  [西] 杉山晴紀        2600       曇         芝
# 202110040812   8.0    464(0)    [西] 谷潔        2600       曇         芝
# 202110040812   9.0  502(-10)    [西] 昆貢        2600       曇         芝
# 202110040812   6.0   436(+2)  [西] 辻野泰之        2600       曇         芝
# 202110040812  11.0   486(-2)   [西] 森秀行        2600       曇         芝
#
#              ground_state        date    horse_id jockey_id
# 202101010101            良  2021年6月12日  2018105875     01181
# 202101010101            良  2021年6月12日  2018105258     01140
# 202101010101            良  2021年6月12日  2018101134     01096
# 202101010101            良  2021年6月12日  2018102791     01157
# 202101010101            良  2021年6月12日  2018101539     01015
# ...                   ...         ...         ...       ...
# 202110040812            良   2021年9月5日  2018102912     01186
# 202110040812            良   2021年9月5日  2017100368     00732
# 202110040812            良   2021年9月5日  2018104097     01168
# 202110040812            良   2021年9月5日  2016105133     01115
# 202110040812            良   2021年9月5日  2015110065     01171
#
# [38130 rows x 20 columns]

# %% [markdown]
# # HorseResults class

# %%
#馬の過去成績データを処理するクラス
class HorseResults:
    @staticmethod
    def scrape(horse_id_list):
        """
        馬の過去成績データをスクレイピングする関数

        Parameters:
        ----------
        horse_id_list : list
            馬IDのリスト

        Returns:
        ----------
        horse_results_df : pandas.DataFrame
            全馬の過去成績データをまとめてDataFrame型にしたもの
        """

        #horse_idをkeyにしてDataFrame型を格納
        horse_results = {}
        for horse_id in tqdm(horse_id_list):
            try:
                url = 'https://db.netkeiba.com/horse/' + horse_id
                df = pd.read_html(url)[3]
                #受賞歴がある馬の場合、3番目に受賞歴テーブルが来るため、4番目のデータを取得する
                if df.columns[0]=='受賞歴':
                    df = pd.read_html(url)[4]
                df.index = [horse_id] * len(df)
                horse_results[horse_id] = df
                time.sleep(1)
            except IndexError:
                continue
            except Exception as e:
                print(e)
                break
            except:
                break

        #pd.DataFrame型にして一つのデータにまとめる        
        horse_results_df = pd.concat([horse_results[key] for key in horse_results])

        return horse_results_df

# %%
horse_id_list = results['horse_id'].astype(str).unique()
horse_results = HorseResults.scrape(horse_id_list)
horse_results #jupyterで出力
# Out:
#   0%|          | 0/11495 [00:00<?, ?it/s]
#                     日付    開催 天気    R       レース名  映像    頭数   枠番  馬番   オッズ  ...  \
# 2018101626  2021/10/04    盛岡  晴  9.0     アンタレス賞 NaN  12.0  6.0   8   7.9  ...
# 2018101626  2021/09/05  2札幌8  晴  8.0  3歳以上1勝クラス NaN  14.0  6.0   9  38.7  ...
# 2018101626  2021/04/11  3中山6  晴  7.0    3歳1勝クラス NaN  10.0  1.0   1  52.9  ...
# 2018101626  2021/03/27  3中山1  晴  6.0    3歳1勝クラス NaN   8.0  8.0   8  72.1  ...
# 2018101626  2021/03/13  2中山5  雨  7.0    3歳1勝クラス NaN  11.0  6.0   7  99.2  ...
# ...                ...   ... ..  ...        ...  ..   ...  ...  ..   ...  ...
# 2014102720  2017/02/19  2京都8  晴  2.0      3歳未勝利 NaN  16.0  8.0  16   9.2  ...
# 2014102720  2017/02/12  2京都6  晴  5.0      3歳未勝利 NaN  16.0  5.0  10  33.3  ...
# 2014102720  2017/01/21  1京都6  晴  5.0      3歳未勝利 NaN  14.0  5.0   8   8.4  ...
# 2014102720  2016/12/25  5阪神9  晴  4.0      2歳未勝利 NaN  15.0  1.0   1  10.4  ...
# 2014102720  2016/12/11  4中京4  晴  5.0       2歳新馬 NaN   9.0  5.0   5  30.2  ...
#
#              着差 ﾀｲﾑ指数       通過        ペース    上り       馬体重 厩舎ｺﾒﾝﾄ  備考  \
# 2018101626 -0.1    **  6-5-4-4   0.0-37.6  37.1   460(-6)    NaN NaN
# 2018101626  0.5    **  5-5-4-4  37.4-36.5  36.7  466(+16)    NaN NaN
# 2018101626  0.8    **  5-6-6-5  38.0-34.7  34.6   450(+2)    NaN NaN
# 2018101626  1.2    **  8-8-8-8  36.3-36.6  36.3   448(+4)    NaN NaN
# 2018101626  2.9    **  9-9-7-8  37.5-38.2  40.5    444(0)    NaN NaN
# ...         ...   ...      ...        ...   ...       ...    ...  ..
# 2014102720  0.3    **      2-2  35.2-38.6  38.8   480(-4)    NaN NaN
# 2014102720  1.6    **      1-1  35.0-37.0  38.6    484(0)    NaN NaN
# 2014102720  2.4    **  2-2-2-2  36.5-36.0  38.3   484(-2)    NaN NaN
# 2014102720  0.4    **  1-1-1-1  37.4-36.8  37.2   486(-4)    NaN NaN
# 2014102720  0.4    **  1-1-1-1  38.8-34.5  34.9    490(0)    NaN NaN
#
#               勝ち馬(2着馬)     賞金
# 2018101626  (アラモードバイオ)  100.0
# 2018101626     ペドラフォルカ    NaN
# 2018101626     ミヤビハイディ    NaN
# 2018101626    スペシャルドラマ    NaN
# 2018101626   ヴァイスメテオール    NaN
# ...                ...    ...
# 2014102720   クリノアントニヌス  130.0
# 2014102720     ゴールドハット    NaN
# 2014102720   エスピリトゥオーゾ    NaN
# 2014102720   ウィズワンアセント    NaN
# 2014102720    ダノンキングダム  280.0
#
# [201720 rows x 28 columns]

# %%
save_path = '/Users/rince/Desktop/Horse/Data/horse_2020.csv'
horse_results.to_csv(save_path)

# %% [markdown]
# # Peds class

# %%
#血統データを処理するクラス
class Peds:
    @staticmethod
    def scrape(horse_id_list):
        """
        血統データをスクレイピングする関数

        Parameters:
        ----------
        horse_id_list : list
            馬IDのリスト

        Returns:
        ----------
        peds_df : pandas.DataFrame
            全血統データをまとめてDataFrame型にしたもの
        """

        peds_dict = {}
        for horse_id in tqdm(horse_id_list):
            try:
                url = "https://db.netkeiba.com/horse/ped/" + horse_id
                df = pd.read_html(url)[0]

                #重複を削除して1列のSeries型データに直す
                generations = {}
                for i in reversed(range(5)):
                    generations[i] = df[i]
                    df.drop([i], axis=1, inplace=True)
                    df = df.drop_duplicates()
                ped = pd.concat([generations[i] for i in range(5)]).rename(horse_id)

                peds_dict[horse_id] = ped.reset_index(drop=True)
                time.sleep(1)
            except IndexError:
                continue
            except Exception as e:
                print(e)
                break
            except:
                break

        #列名をpeds_0, ..., peds_61にする
        peds_df = pd.concat([peds_dict[key] for key in peds_dict], axis=1).T.add_prefix('peds_')

        return peds_df

# %%
peds_2021 = Peds.scrape(horse_id_list)
peds_2021
# Out:
#   0%|          | 0/10260 [00:00<?, ?it/s]
#                                                       peds_0  \
# 2018105875                    ダイワメジャー 2001 栗毛 [血統][産駒] Halo系
# 2018105258                 エピファネイア 2010 鹿毛 [血統][産駒] Roberto系
# 2018101134                    ミッキーアイル 2011 鹿毛 [血統][産駒] Halo系
# 2018102791              Kingman (英) 2011 鹿毛 [血統][産駒] Danzig系
# 2018101539                 カレンブラックヒル 2009 黒鹿毛 [血統][産駒] Halo系
# ...                                                      ...
# 2019104476      Key Partner   Northern Dancer   Lady Victoria      Caro
# 2019100665     Golden Trail        Storm Bird       Terlingua  Damascus
# 2019101487        Glenveagh   Northern Dancer   Lady Victoria     Dewan
# 2018100090      Priddy Fair   Northern Dancer   Lady Victoria      ツイッグ
#
#                    peds_61
# 2018105875     Three Roses
# 2018105258           Pedra
# 2018101134       Cream Pie
# 2018102791  La Dame Du Lac
# 2018101539       Brabantia
# ...                    ...
# 2019105283           Olmec
# 2019104476          Jedina
# 2019100665            Fiji
# 2019101487     ハニーサツクルヴアイン
# 2018100090         ホースメンケイ
#
# [10260 rows x 62 columns]

# %%
save_path = '/Users/rince/Desktop/Horse/Data/peds_2021.csv'
peds_2021.to_csv(save_path)

# %% [markdown]
# # Return class

# %%
#払い戻し表データを処理するクラス
class Return:
    @staticmethod
    def scrape(race_id_list):
        """
        払い戻し表データをスクレイピングする関数

        Parameters:
        ----------
        race_id_list : list
            レースIDのリスト

        Returns:
        ----------
        return_tables_df : pandas.DataFrame
            全払い戻し表データをまとめてDataFrame型にしたもの
        """

        return_tables = {}
        for race_id in tqdm(race_id_list):
            try:
                url = "https://db.netkeiba.com/race/" + race_id

                #普通にスクレイピングすると複勝やワイドなどが区切られないで繋がってしまう。
                #そのため、改行コードを文字列brに変換して後でsplitする
                f = urllib.request.urlopen(url)
                html = f.read()
                html = html.replace(b'<br />', b'br')
                dfs = pd.read_html(html)

                #dfsの1番目に単勝〜馬連、2番目にワイド〜三連単がある
                df = pd.concat([dfs[1], dfs[2]])

                df.index = [race_id] * len(df)
                return_tables[race_id] = df
                time.sleep(1)
            except IndexError:
                continue
            except Exception as e:
                print(e)
                break
            except:
                break

        #pd.DataFrame型にして一つのデータにまとめる
        return_tables_df = pd.concat([return_tables[key] for key in return_tables])
        return return_tables_df

# %% [markdown]
# # Update func

# %%
def update_data(old, new):
    """
    Parameters:
    ----------
    old : pandas.DataFrame
        古いデータ
    new : pandas.DataFrame
        新しいデータ
    """

    filtered_old = old[~old.index.isin(new.index)]
    return pd.concat([filtered_old, new])

# %%
returns_2021 = Return.scrape(race_id_list)
returns_2021
# Out:
#   0%|          | 0/38130 [00:00<?, ?it/s]
#                 0                      1                     2           3
# 202101010101   単勝                      9                  1350           7
# 202101010101   複勝               9br6br14       340br170br2,190    7br1br14
# 202101010101   枠連                  3 - 5                   660           2
# 202101010101   馬連                  6 - 9                  2580          13
# 202101010101  ワイド  6 - 9br9 - 14br6 - 14  1,040br14,560br6,440  14br77br47
# ...           ...                    ...                   ...         ...
# 202110040812   馬連                 3 - 11                  2270           9
# 202110040812  ワイド  3 - 11br4 - 11br3 - 4         660br190br260     9br1br2
# 202110040812   馬単                 11 → 3                  3520          14
# 202110040812  三連複             3 - 4 - 11                  1200           3
# 202110040812  三連単             11 → 3 → 4                  9960          27
#
# [21932 rows x 4 columns]

# %%
save_path = '/Users/rince/Desktop/Horse/Data/returns_2021.csv'
returns_2021.to_csv(save_path)
